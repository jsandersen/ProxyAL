# %%
import sys, os
cwd = os.getcwd()
sys.path.append(cwd + '/../.')

# %%
from src.plot import plot_f1
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = (10,10)
plt.rcParams.update({'font.size': 22})

# %%
dataset = 'reuters'
encoding = 'elmo'
index = None
sampler = ['unc', 'unc_density', 'isli', 'isli_density', 'isls', 'isls_density']
colors = ['b', 'g', 'r', 'c', 'm', 'y']
name = 'final'

dirs = [f'./res/{dataset}_{encoding}_{x}_{name}_1_100_5' for x in sampler]

dir_rnd = f'./res/{dataset}_{encoding}_unc_{name}_rnd_1_100_5'
color_rnd = 'black'
label_rnd = 'random'

def plot_balancy(load_dir):
    c_list = np.load('%s/class_distributions.npy' % load_dir, allow_pickle=True)
    plot_c(c_list)

# %%
plot_balancy(dirs[0])
plot_balancy(dir_rnd)

# %%
    query_strategy = 'unc'
    name_postfix = ''
    if query_strategy == 'rnd':
        name_postfix = "_rnd"
        query_strategy = 'unc'
    load_dir = f'./res/{dataset}_{encoding}_{str(query_strategy)}_{name}{name_postfix}_1_100_5'

    f1_micros = [] 
    f1_macros = []
    
    c_list = np.load('%s/class_distributions.npy' % load_dir, allow_pickle=True)

# %%
meta_l = []
for k in range(5):
    l = [[] for i in range(len(c_list[0, k]))]

    for i in c_list[k]:
        for j in range(len(i)):
            l[j].append(i[j])
            
    meta_l.append(l)
np.array(meta_l).mean(axis=0)

# %%
# Out:
# (3, 501)

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

def plot_c(c_list):
    meta_l = []
    for k in range(5):
        l = [[] for i in range(len(c_list[0, k]))]

        for i in c_list[k]:
            for j in range(len(i)):
                l[j].append(i[j])

        meta_l.append(l)
    meta_l=np.array(meta_l).mean(axis=0)

    groups = {f'group_{i}':meta_l[i] for i in range(len(l))}

    # Make data
    data = pd.DataFrame(groups)

    # We need to transform the data from raw data to percentage (fraction)
    data_perc = data.divide(data.sum(axis=1), axis=0)
    groups_list = [data_perc[f'group_{i}'] for i in range(len(l))]

    # Make the plot
    plt.stackplot(range(501),  *groups_list, labels=['A','B','C'])
    #plt.legend(loc='upper left')
    plt.margins(0,0)
    plt.title('100 % stacked area chart')
    plt.show()

# %%
plot_c(c_list)

# %%
plot_c(c_list)

# %%
dataset = 'app_store'
encoding = 'sbert'
sampler = ['unc', 'unc_density', 'isli', 'isli_density', 'isls', 'isls_density']
colors = ['b', 'g', 'r', 'c', 'm', 'y']
name = 'test'

dirs = [f'./res/{dataset}_{encoding}_{x}_{name}_1_100_5' for x in sampler]

dir_rnd = f'./res/{dataset}_{encoding}_unc_{name}_rnd_1_100_5'
color_rnd = 'black'
label_rnd = 'random'
plot_f1(dirs + [dir_rnd], colors + [color_rnd], sampler + [label_rnd], dataset, encoding, name)
# Out:
# unc :  0.8269
# unc_density :  0.8272
# isli :  0.8287
# isli_density :  0.8315
# isls :  0.8306
# isls_density :  0.8315
# random :  0.8059
# unc :  0.0082
# unc_density :  0.005
# isli :  0.0061
# isli_density :  0.0014
# isls :  0.0044
# isls_density :  0.0066
# random :  0.0081
# unc :  0.7755
# unc_density :  0.7779
# isli :  0.778
# isli_density :  0.7831
# isls :  0.7818
# isls_density :  0.7831
# random :  0.7231
# unc :  0.0112
# unc_density :  0.007
# isli :  0.0072
# isli_density :  0.0025
# isls :  0.0058
# isls_density :  0.0092
# random :  0.0212

# %%
dataset = 'imdb'
encoding = 'sbert'
sampler = ['unc', 'unc_density', 'isli', 'isli_density', 'isls', 'isls_density']
colors = ['b', 'g', 'r', 'c', 'm', 'y']

dirs = [f'./res/{dataset}_{encoding}_{x}_test_1_100_5' for x in sampler]

dir_rnd = f'./res/{dataset}_{encoding}_unc_test_rnd_1_100_5'
color_rnd = 'black'
label_rnd = 'random'
plot_f1(dirs + [dir_rnd], colors + [color_rnd], sampler + [label_rnd])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3508/1009206524.py in <module>
#       9 color_rnd = 'black'
#      10 label_rnd = 'random'
# ---> 11 plot_f1(dirs + [dir_rnd], colors + [color_rnd], sampler + [label_rnd])
#
# TypeError: plot_f1() missing 3 required positional arguments: 'dataset', 'encoding', and 'name'

# %%
dataset = 'app_store'
encoding = 'bert'
sampler = ['unc', 'unc_density', 'isli', 'isli_density', 'isls', 'isls_density']
colors = ['b', 'g', 'r', 'c', 'm', 'y']

dirs = [f'./res/{dataset}_{encoding}_{x}_test_1_100_5' for x in sampler]

dir_rnd = f'./res/{dataset}_{encoding}_unc_test_rnd_1_100_5'
color_rnd = 'black'
label_rnd = 'random'
plot_f1(dirs + [dir_rnd], colors + [color_rnd], sampler + [label_rnd])

# %%
dataset = 'imdb'
encoding = 'sbert'
sampler = ['unc', 'unc_density', 'isli', 'isli_density', 'isls', 'isls_density']
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'black']

dirs = [f'./res/{dataset}_{encoding}_{x}_test_1_100_5' for x in sampler]

dir_rnd = f'./res/{dataset}_{encoding}_unc_test_rnd_1_100_5'
color_rnd = 'black'
label_rnd = 'random'
plot_f1(dirs + [dir_rnd], colors + [color_rnd], sampler + [label_rnd])

# %%
dataset = 'imdb'
encoding = 'sif'
sampler = ['unc', 'unc_density', 'isli', 'isli_density', 'isls', 'isls_density']
colors = ['b', 'g', 'r', 'c', 'm', 'y']

dirs = [f'./res/{dataset}_{encoding}_{x}_test_1_100_5' for x in sampler]

dir_rnd = f'./res/{dataset}_{encoding}_unc_test_rnd_1_100_5'
color_rnd = 'black'
label_rnd = 'random'
plot_f1(dirs + [dir_rnd], colors + [color_rnd], sampler + [label_rnd])

# %%
dataset = 'imdb'
encoding = 'sif'
sampler = ['unc', 'unc_density', 'isli', 'isli_density', 'isls', 'isls_density']
colors = ['b', 'g', 'r', 'c', 'm', 'y']

dirs = [f'./res/{dataset}_{encoding}_{x}_test_1_100_5' for x in sampler]

dir_rnd = f'./res/{dataset}_{encoding}_unc_test_rnd_1_100_5'
color_rnd = 'black'
label_rnd = 'random'
plot_f1(dirs + [dir_rnd], colors + [color_rnd], sampler + [label_rnd])

# %%
dataset = 'imdb'
encoding = 'elmo'
sampler = ['unc', 'unc_density', 'isli', 'isli_density', 'isls', 'isls_density']
colors = ['b', 'g', 'r', 'c', 'm', 'y']

dirs = [f'./res/{dataset}_{encoding}_{x}_test_1_100_5' for x in sampler]

dir_rnd = f'./res/{dataset}_{encoding}_unc_test_rnd_1_100_5'
color_rnd = 'black'
label_rnd = 'random'

plot_f1(dirs + [dir_rnd], colors + [color_rnd], sampler + [label_rnd])

# %%
dataset = 'imdb'
encoding = 'sbert'
sampler = ['unc', 'unc_density', 'isli', 'isli_density', 'isls', 'isls_density']
colors = ['b', 'g', 'r', 'c', 'm', 'y']

dirs = [f'./res/{dataset}_{encoding}_{x}_test_1_100_5' for x in sampler]
dir_rnd = f'./res/{dataset}_{encoding}_unc_test_rnd_1_100_5'
color_rnd = 'black'
label_rnd = 'random'

plot_f1(dirs + [dir_rnd], colors + [color_rnd], sampler + [label_rnd])

# %%
### end

# %%
# /app_store_sbert_isls_density_test_1_100_1

# %%
expA_dir = f'./res/app_store_sbert_unc_test_1_30_1'
f1_mic_list_A, f1_mac_list_A, _, _, _, _ = load_results(expA_dir)
mean_f1_mic_A, std_f1_mic_A = get_mean_and_std(f1_mic_list_A)
mean_f1_mac_A, std_f1_mac_A = get_mean_and_std(f1_mac_list_A)

# %%
a = prepare(mean_f1_mic_A, 1)
plt.plot(a[:, 0], a[:, 1], color='orange')

# %%
expA_dir = f'./app_store_sbert_unc_test_1_30_1'
f1_mic_list_A, f1_mac_list_A, _, _, _, _ = load_results(expA_dir)
mean_f1_mic_A, std_f1_mic_A = get_mean_and_std(f1_mic_list_A)
mean_f1_mac_A, std_f1_mac_A = get_mean_and_std(f1_mac_list_A)

a = 'unc_density'
expA_rnd_dir = f'./app_store_sbert_{a}_test_1_100_1'
f1_mic_list_A_rnd, f1_mac_list_A_rnd, _, _, _, _ = load_results(expA_rnd_dir)
mean_f1_mic_A_rnd, std_f1_mic_A_rnd = get_mean_and_std(f1_mic_list_A_rnd)
mean_f1_mac_A_rnd, std_f1_mac_A_rnd = get_mean_and_std(f1_mac_list_A_rnd)

a = 'unc_isls'
expB_dir = f'./app_store_sbert_{a}_test_1_100_1'
f1_mic_list_B, f1_mac_list_B, _, _, _, _ = load_results(expB_dir)
mean_f1_mic_B, std_f1_mic_B = get_mean_and_std(f1_mic_list_B)
mean_f1_mac_B, std_f1_mac_B = get_mean_and_std(f1_mac_list_B)

a = 'isli'
expB_rnd_dir = f'./app_store_sbert_{a}_test_1_100_1'
f1_mic_list_B_rnd, f1_mac_list_B_rnd, _, _, _, _ = load_results(expB_rnd_dir)
mean_f1_mic_B_rnd, std_f1_mic_B_rnd = get_mean_and_std(f1_mic_list_B_rnd)
mean_f1_mac_B_rnd, std_f1_mac_B_rnd = get_mean_and_std(f1_mac_list_B_rnd)

a = 'isli_density'
expC_dir = f'./app_store_sbert_{a}_test_1_100_1'
f1_mic_list_C, f1_mac_list_C, _, _, _, _ = load_results(expC_dir)
mean_f1_mic_C, std_f1_mic_C = get_mean_and_std(f1_mic_list_C)
mean_f1_mac_C, std_f1_mac_C = get_mean_and_std(f1_mac_list_C)

a = 'isls'
expC_rnd_dir = f'./app_store_sbert_{a}_test_1_100_1'
f1_mic_list_C_rnd, f1_mac_list_C_rnd, _, _, _, _ = load_results(expC_rnd_dir)
mean_f1_mic_C_rnd, std_f1_mic_C_rnd = get_mean_and_std(f1_mic_list_C_rnd)
mean_f1_mac_C_rnd, std_f1_mac_C_rnd = get_mean_and_std(f1_mac_list_C_rnd)


a = 'isls_density'
expD_dir = f'./app_store_sbert_{a}_test_1_100_1'
f1_mic_list_D, f1_mac_list_D, _, _, _, _ = load_results(expD_dir)
mean_f1_mic_D, std_f1_mic_D = get_mean_and_std(f1_mic_list_D)
mean_f1_mac_D, std_f1_mac_D = get_mean_and_std(f1_mac_list_D)

# %%
a = prepare(mean_f1_mic_A, 1)
b = prepare(mean_f1_mic_B, 1)
c = prepare(mean_f1_mic_C, 1)

a_rnd = prepare(mean_f1_mic_A_rnd, 1)
b_rnd = prepare(mean_f1_mic_B_rnd, 1)
c_rnd = prepare(mean_f1_mic_C_rnd, 1)

plt.plot(a[:, 0], a[:, 1], color='orange')
plt.plot(b[:, 0], b[:, 1], color='blue')
plt.plot(c[:, 0], c[:, 1], color='green')

plt.plot(a_rnd[:, 0], a_rnd[:, 1], color='black', ls='dotted')
plt.plot(b_rnd[:, 0], b_rnd[:, 1], color='blue', ls='dotted')
plt.plot(c_rnd[:, 0], c_rnd[:, 1], color='green', ls='dotted')
plt.show()

# %%
a = prepare(mean_f1_mac_A, 1)
b = prepare(mean_f1_mac_B, 1)
c = prepare(mean_f1_mac_C, 1)

a_rnd = prepare(mean_f1_mac_A_rnd, 1)
#b_rnd = prepare(mean_f1_mac_B_rnd, 10)
#c_rnd = prepare(mean_f1_mac_C_rnd, 20)

plt.plot(a[:, 0], a[:, 1], color='orange')
plt.plot(b[:, 0], b[:, 1], color='blue')
plt.plot(c[:, 0], c[:, 1], color='green')

plt.plot(a_rnd[:, 0], a_rnd[:, 1], color='black', ls='dotted')
#plt.plot(b_rnd[:, 0], b_rnd[:, 1], color='blue', ls='dotted')
#plt.plot(c_rnd[:, 0], c_rnd[:, 1], color='green', ls='dotted')
plt.show()

# %%
## F1 Scores

# %%
expA_dir = './app_store_sbert_1_500_1'
f1_mic_list_A, f1_mac_list_A, _, _, _, _ = load_results(expA_dir)
mean_f1_mic_A, std_f1_mic_A = get_mean_and_std(f1_mic_list_A)
mean_f1_mac_A, std_f1_mac_A = get_mean_and_std(f1_mac_list_A)

expA_rnd_dir = './app_store_sbert_rnd_1_500_1'
f1_mic_list_A_rnd, f1_mac_list_A_rnd, _, _, _, _ = load_results(expA_rnd_dir)
mean_f1_mic_A_rnd, std_f1_mic_A_rnd = get_mean_and_std(f1_mic_list_A_rnd)
mean_f1_mac_A_rnd, std_f1_mac_A_rnd = get_mean_and_std(f1_mac_list_A_rnd)

expB_dir = './app_store_sbert_10_50_1'
f1_mic_list_B, f1_mac_list_B, _, _, _, _ = load_results(expB_dir)
mean_f1_mic_B, std_f1_mic_B = get_mean_and_std(f1_mic_list_B)
mean_f1_mac_B, std_f1_mac_B = get_mean_and_std(f1_mac_list_B)

expB_rnd_dir = './app_store_sbert_rnd_10_50_1'
f1_mic_list_B_rnd, f1_mac_list_B_rnd, _, _, _, _ = load_results(expB_rnd_dir)
mean_f1_mic_B_rnd, std_f1_mic_B_rnd = get_mean_and_std(f1_mic_list_B_rnd)
mean_f1_mac_B_rnd, std_f1_mac_B_rnd = get_mean_and_std(f1_mac_list_B_rnd)

expC_dir = './app_store_sbert2_20_25_1'
f1_mic_list_C, f1_mac_list_C, _, _, _, _ = load_results(expC_dir)
mean_f1_mic_C, std_f1_mic_C = get_mean_and_std(f1_mic_list_C)
mean_f1_mac_C, std_f1_mac_C = get_mean_and_std(f1_mac_list_C)

expC_rnd_dir = './app_store_sbert_rnd_20_25_1'
f1_mic_list_C_rnd, f1_mac_list_C_rnd, _, _, _, _ = load_results(expC_rnd_dir)
mean_f1_mic_C_rnd, std_f1_mic_C_rnd = get_mean_and_std(f1_mic_list_C_rnd)
mean_f1_mac_C_rnd, std_f1_mac_C_rnd = get_mean_and_std(f1_mac_list_C_rnd)

# %%
a = prepare(mean_f1_mic_A, 1)
b = prepare(mean_f1_mic_B, 10)
c = prepare(mean_f1_mic_C, 20)

a_rnd = prepare(mean_f1_mic_A_rnd, 1)
#b_rnd = prepare(mean_f1_mic_B_rnd, 10)
#c_rnd = prepare(mean_f1_mic_C_rnd, 20)

plt.plot(a[:, 0], a[:, 1], color='orange')
plt.plot(b[:, 0], b[:, 1], color='blue')
plt.plot(c[:, 0], c[:, 1], color='green')

plt.plot(a_rnd[:, 0], a_rnd[:, 1], color='black', ls='dotted')
#plt.plot(b_rnd[:, 0], b_rnd[:, 1], color='blue', ls='dotted')
#plt.plot(c_rnd[:, 0], c_rnd[:, 1], color='green', ls='dotted')
plt.show()

# %%
a = prepare(std_f1_mic_A, 1)
b = prepare(std_f1_mic_B, 10)
c = prepare(std_f1_mic_C, 20)

a_rnd = prepare(std_f1_mic_A_rnd, 1)
#b_rnd = prepare(std_f1_mic_B_rnd, 10)
#c_rnd = prepare(std_f1_mic_C_rnd, 20)

plt.plot(a[:, 0], a[:, 1], color='orange')
plt.plot(b[:, 0], b[:, 1], color='blue')
plt.plot(c[:, 0], c[:, 1], color='green')

plt.plot(a_rnd[:, 0], a_rnd[:, 1], color='black', ls='dotted')
#plt.plot(b_rnd[:, 0], b_rnd[:, 1], color='blue', ls='dotted')
#plt.plot(c_rnd[:, 0], c_rnd[:, 1], color='green', ls='dotted')
plt.show()

# %%
a = prepare(mean_f1_mac_A, 1)
b = prepare(mean_f1_mac_B, 10)
c = prepare(mean_f1_mac_C, 20)

a_rnd = prepare(mean_f1_mac_A_rnd, 1)
#b_rnd = prepare(mean_f1_mac_B_rnd, 10)
#c_rnd = prepare(mean_f1_mac_C_rnd, 20)

plt.plot(a[:, 0], a[:, 1], color='orange')
plt.plot(b[:, 0], b[:, 1], color='blue')
plt.plot(c[:, 0], c[:, 1], color='green')

plt.plot(a_rnd[:, 0], a_rnd[:, 1], color='black', ls='dotted')
#plt.plot(b_rnd[:, 0], b_rnd[:, 1], color='blue', ls='dotted')
#plt.plot(c_rnd[:, 0], c_rnd[:, 1], color='green', ls='dotted')
plt.show()

# %%
a = prepare(std_f1_mac_A, 1)
b = prepare(std_f1_mac_B, 10)
c = prepare(std_f1_mac_C, 20)

a_rnd = prepare(std_f1_mac_A_rnd, 1)

plt.plot(a[:, 0], a[:, 1], color='orange')
plt.plot(b[:, 0], b[:, 1], color='blue')
plt.plot(c[:, 0], c[:, 1], color='green')

plt.plot(a_rnd[:, 0], a_rnd[:, 1], color='black', ls='dotted')

plt.show()

# %%
expA_dir = './app_store_sbert_1_300_1'
f1_mic_list, f1_mac_list, c_list, times_train_list, times_inf_list, used_index_meta_list = load_results(expA_dir)
mean_f1_mic, std_f1_mic = get_mean_and_std(f1_mic_list)

plt.plot(mean_f1_mic)


expA_dir = './app_store_sbert_10_30_1'
f1_mic_list, f1_mac_list, c_list, times_train_list, times_inf_list, used_index_meta_list = load_results(expA_dir)
mean_f1_mic, std_f1_mic = get_mean_and_std(f1_mic_list)

plt.plot(mean_f1_mic)

expA_dir = './app_store_sbert_20_15_1'
f1_mic_list, f1_mac_list, c_list, times_train_list, times_inf_list, used_index_meta_list = load_results(expA_dir)
mean_f1_mic, std_f1_mic = get_mean_and_std(f1_mic_list)

plt.plot(mean_f1_mic)

# %%
expA_dir = './app_store_sbert_20_15_1'
f1_mic_list, f1_mac_list, c_list, times_train_list, times_inf_list, used_index_meta_list = load_results(expA_dir)
mean_f1_mic, std_f1_mic = get_mean_and_std(f1_mic_list)

plt.plot(mean_f1_mic)
plt.show()
plt.plot(std_f1_mic)

# %%
## Time

# %%
mean_train_time = np.array(times_train_list).mean(axis=0)
std_train_time = np.array(times_train_list).std(axis=0)

# %%
plt.plot(mean_train_time)

# %%
plt.plot(std_train_time)

# %%
mean_inf_time = np.array(times_inf_list).mean(axis=0)
std_inf_time = np.array(times_inf_list).std(axis=0)

# %%
plt.plot(mean_inf_time)

# %%
plt.plot(std_inf_time)
